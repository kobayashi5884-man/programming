# %%
#3-A
i=0;
while i<1000:
    print('Hello World')
    i=i+1
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# ...

# %%
#3-B
i=1
while True:
    x=int(input())
    if x==0:
        break
    print('Case '+str(i)+': '+str(x))
    i=i+1
# Out:
# 3
# Case 1: 3
# 5
# Case 2: 5
# 0

# %%
#3-C
while True:
    a,b=map(int,input().split())
    if a==0 and b==0:
        break
    if a>b:
        print(b,a)
    else :
        print(a,b)
# Out:
# 3 2
# 2 3
# 5 3
# 3 5
# 2 2
# 2 2
# 0 0

# %%
#3-D
a,b,c=map(int,input().split())
x=0
for i in range(a,b+1):
    if c%i==0:
        x=x+1

print(str(x))
# Out:
# 5 14 80
# 3
